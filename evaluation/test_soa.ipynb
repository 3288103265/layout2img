# %%
import pickle as pkl

with open('/home/wangph/layout2img/outputs/base2_2/samples_G25/detection.pkl', 'rb') as f:
    res = pkl.load(f)
res
# Out:
# {'sample2492_4.jpg': [['person', 'sports ball'],
#   [0, 32],
#   [[array(0.40503538, dtype=float32),
#     array(0.03550632, dtype=float32),
#     array(0.32107306, dtype=float32),
#     array(0.9347871, dtype=float32)],
#    [array(0.7278105, dtype=float32),
#     array(0.59262156, dtype=float32),
#     array(0.08686423, dtype=float32),
#     array(0.12075591, dtype=float32)]]],
#  'sample2508_2.jpg': [['bicycle', 'bicycle'],
#   [1, 1],
#   [[array(0.33055982, dtype=float32),
#     array(0.45091686, dtype=float32),
#     array(0.49131206, dtype=float32),
#     array(0.52887774, dtype=float32)],
#    [array(0.0185557, dtype=float32),
#     array(0.46153462, dtype=float32),
#     array(0.28410718, dtype=float32),
#     array(0.52529013, dtype=float32)]]],
#  'sample1944_2.jpg': [['horse', 'horse'],
#   [17, 17],
#   [[array(0.00324185, dtype=float32),
#     array(0.15635031, dtype=float32),
#     array(0.56869954, dtype=float32),
#     array(0.7583241, dtype=float32)],
# ...

# %%
import random
box = res[random.choice(list(res.keys()))]
box
# Out:
# [['horse', 'horse'],
#  [17, 17],
#  [[array(0.1669804, dtype=float32),
#    array(0.09405333, dtype=float32),
#    array(0.7325515, dtype=float32),
#    array(0.8676801, dtype=float32)],
#   [array(0.4093415, dtype=float32),
#    array(0.09768182, dtype=float32),
#    array(0.5582205, dtype=float32),
#    array(0.7513058, dtype=float32)]]]

# %%
import numpy as np

bbox = np.array(box)
bbox
# Out:
# array([[0.40503538, 0.03550632, 0.32107306, 0.9347871 ],
#        [0.7278105 , 0.59262156, 0.08686423, 0.12075591]], dtype=float32)

# %%
# Out:
# 'sample682_0.jpg'
